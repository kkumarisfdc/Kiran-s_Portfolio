# %% [markdown]
# <a href="https://colab.research.google.com/github/kkumarisfdc/Kiran-s_Portfolio/blob/main/Day_44_Delivery_Systems_%26_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data ={
    "Sequence":[
        "MSTNPKPQRKTKRNTNRRPQDVKFPGG",
        "MSKQLATAVAAALAGGAAAAAAAVVV",
        "MPEKKKKRRRRKKKKGGGGTTTTAAA",
        "MAVAAAGGGVVVVVVVVLLLLIIIII",
        "MPKRRRRRRRRRRRQQQQQQQQQQ00",
        "MATGGGGGGVVVVVVVVVVAAAAGGG",
        "MKKKKKKKKKKKKTTTGGGAAAATTT",
        "MAVVVVLLLLGGGGAAAATTTCCCCC",
        "MQQQQQGGGGVVVVAAAATTTGGGGG",
        "MKKRRTTGGGGCCCCAAAATTTGGGG"
    ],

"Length": [31,30,31,31,31, 31,31,31,31,31],
"Hydrophobicity": [0.61,0.82,0.45,0.91,0.30,0.84,0.40,0.78,0.70,0.55],
"Charge": [4,1,8,0,9,1,10,2,3,5],
"GC_Content": [48,55,46,58,44,60,45,57,54,50],
"Target": ["Liver","Muscle","Brain","Muscle","Brain","Muscle","Brain","Liver","Liver","Brain"]
}
df = pd.DataFrame(data)

df.to_csv("aav_capsid.csv", index=False)

print("CSV file created successfully!")

df.head()
# Out:
# CSV file created successfully!
#                       Sequence  Length  Hydrophobicity  Charge  GC_Content  \
# 0  MSTNPKPQRKTKRNTNRRPQDVKFPGG      31            0.61       4          48
# 1   MSKQLATAVAAALAGGAAAAAAAVVV      30            0.82       1          55
# 2   MPEKKKKRRRRKKKKGGGGTTTTAAA      31            0.45       8          46
# 3   MAVAAAGGGVVVVVVVVLLLLIIIII      31            0.91       0          58
# 4   MPKRRRRRRRRRRRQQQQQQQQQQ00      31            0.30       9          44
#
#    Target
# 0   Liver
# 1  Muscle
# 2   Brain
# 3  Muscle
# 4   Brain

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

df = pd.read_csv("aav_capsid.csv")
df.head()
# Out:
#                       Sequence  Length  Hydrophobicity  Charge  GC_Content  \
# 0  MSTNPKPQRKTKRNTNRRPQDVKFPGG      31            0.61       4          48
# 1   MSKQLATAVAAALAGGAAAAAAAVVV      30            0.82       1          55
# 2   MPEKKKKRRRRKKKKGGGGTTTTAAA      31            0.45       8          46
# 3   MAVAAAGGGVVVVVVVVLLLLIIIII      31            0.91       0          58
# 4   MPKRRRRRRRRRRRQQQQQQQQQQ00      31            0.30       9          44
#
#    Target
# 0   Liver
# 1  Muscle
# 2   Brain
# 3  Muscle
# 4   Brain

# %%
df["Target"] = encoder.fit_transform(df["Target"])
print(df)
# Out:
#                       Sequence  Length  Hydrophobicity  Charge  GC_Content  \
# 0  MSTNPKPQRKTKRNTNRRPQDVKFPGG      31            0.61       4          48
# 1   MSKQLATAVAAALAGGAAAAAAAVVV      30            0.82       1          55
# 2   MPEKKKKRRRRKKKKGGGGTTTTAAA      31            0.45       8          46
# 3   MAVAAAGGGVVVVVVVVLLLLIIIII      31            0.91       0          58
# 4   MPKRRRRRRRRRRRQQQQQQQQQQ00      31            0.30       9          44
# 5   MATGGGGGGVVVVVVVVVVAAAAGGG      31            0.84       1          60
# 6   MKKKKKKKKKKKKTTTGGGAAAATTT      31            0.40      10          45
# 7   MAVVVVLLLLGGGGAAAATTTCCCCC      31            0.78       2          57
# 8   MQQQQQGGGGVVVVAAAATTTGGGGG      31            0.70       3          54
# 9   MKKRRTTGGGGCCCCAAAATTTGGGG      31            0.55       5          50
#
#    Target
# 0       1
# 1       2
# 2       0
# 3       2
# 4       0
# 5       2
# 6       0
# 7       1
# 8       1
# 9       0

# %%
X = df[["Length","Hydrophobicity","Charge","GC_Content"]]
y = df["Target"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
pred = model.predict(X_test)
print(pred)
# Out:
# [1 1 2]

# %%
print("Accuracy")
print(accuracy_score(y_test,pred))
print("Classification Report")
print(classification_report(y_test,pred))
# Out:
# Accuracy
# 0.6666666666666666
# Classification Report
#               precision    recall  f1-score   support
#
#            1       0.50      1.00      0.67         1
#            2       1.00      0.50      0.67         2
#
#     accuracy                           0.67         3
#    macro avg       0.75      0.75      0.67         3
# weighted avg       0.83      0.67      0.67         3

# %%
new_capsid = [[31,0.80,2,56]]
prediction = model.predict(new_capsid)
print("Predicted Tissue:")
print(encoder.inverse_transform(prediction))
# Out:
# Predicted Tissue:
# ['Liver']
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": model.feature_importances_
})
importance.sort_values(by="Importance", ascending=False)
# Out:
#           Feature  Importance
# 2          Charge    0.376693
# 1  Hydrophobicity    0.375690
# 3      GC_Content    0.247617
# 0          Length    0.000000
